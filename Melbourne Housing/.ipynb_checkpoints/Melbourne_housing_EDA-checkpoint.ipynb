# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.1 Load the libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.2. Import the dataset(Melbourne_housing_FULL.csv):

# %%
Data  = pd.read_csv('Melbourne_housing_FULL.csv') # Import the dataset 
Data.head()  # view the first 5 rows of the data
# Out:
#          Suburb           Address  Rooms Type Method        SellerG      Date  \
# 0    Abbotsford     68 Studley St      2    h     SS         Jellis  3/9/2016
# 1  Airport West     154 Halsey Rd      3    t     PI         Nelson  3/9/2016
# 2   Albert Park    105 Kerferd Rd      2    h      S  hockingstuart  3/9/2016
# 3   Albert Park  85 Richardson St      2    h      S        Thomson  3/9/2016
# 4    Alphington      30 Austin St      3    h     SN        McGrath  3/9/2016
#
#    Distance  Postcode  Bedroom  ...  Landsize  BuildingArea  YearBuilt  \
# 0       2.5    3067.0      2.0  ...     126.0           inf        NaN
# 1      13.5    3042.0      3.0  ...     303.0           225     2016.0
# 2       3.3    3206.0      2.0  ...     120.0            82     1900.0
# 3       3.3    3206.0      2.0  ...     159.0           inf        NaN
# 4       6.4    3078.0      3.0  ...     174.0           122     2003.0
#
#                   CouncilArea  Latitude Longtitude             Regionname  \
# 0          Yarra City Council  -37.8014   144.9958  Northern Metropolitan
# 1  Moonee Valley City Council  -37.7180   144.8780   Western Metropolitan
# 2   Port Phillip City Council  -37.8459   144.9555  Southern Metropolitan
# 3   Port Phillip City Council  -37.8450   144.9538  Southern Metropolitan
# 4        Darebin City Council  -37.7818   145.0198  Northern Metropolitan
#
#    Propertycount      ParkingArea      Price
# 0         4019.0          Carport        NaN
# 1         3464.0  Detached Garage   840000.0
# 2         3280.0  Attached Garage  1275000.0
# 3         3280.0           Indoor  1455000.0
# 4         2211.0          Parkade        NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.3 Check the Dimension of data

# %%
Data.shape # see the shape of the data
# Out:
# (34857, 22)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.4 Check the Information about the data and the datatypes of each respective attributes.

# %%
### Check for information about the data
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Method         34857 non-null  object
#  5   SellerG        34857 non-null  object
#  6   Date           34857 non-null  object
#  7   Distance       34856 non-null  float64
#  8   Postcode       34856 non-null  float64
#  9   Bedroom        26640 non-null  float64
#  10  Bathroom       26631 non-null  float64
#  11  Car            26129 non-null  float64
#  12  Landsize       23047 non-null  float64
#  13  BuildingArea   13760 non-null  object
#  14  YearBuilt      15551 non-null  float64
#  15  CouncilArea    34854 non-null  object
#  16  Latitude       26881 non-null  float64
#  17  Longtitude     26881 non-null  float64
#  18  Regionname     34857 non-null  object
#  19  Propertycount  34854 non-null  float64
#  20  ParkingArea    34857 non-null  object
#  21  Price          27247 non-null  float64
# dtypes: float64(11), int64(1), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.5 Check for Null Values and replace the same with mean

# %%
Data.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom           8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21097
# YearBuilt        19306
# CouncilArea          3
# Latitude          7976
# Longtitude        7976
# Regionname           0
# Propertycount        3
# ParkingArea          0
# Price             7610
# dtype: int64

# %%
Data[Data.BuildingArea.str.isdigit() == False]
# Out:
#                    Suburb           Address  Rooms Type Method        SellerG  \
# 0              Abbotsford     68 Studley St      2    h     SS         Jellis
# 3             Albert Park  85 Richardson St      2    h      S        Thomson
# 6              Alphington   5/6 Yarralea St      3    h      S         Jellis
# 11           Altona North      103 Sixth Av      4    h      S  hockingstuart
# 12               Armadale        24 Hume St      3    h      S             RT
# ...                   ...               ...    ...  ...    ...            ...
# 30551              Melton        14 Musk Ct      3    h     SP  PRDNationwide
# 30606          Noble Park        6 Helen Ct      3    h     SP         Leyton
# 30767        Surrey Hills       25 James St      5    h      S         Jellis
# 30829        Williamstown   2/70 Osborne St      2    u      S  hockingstuart
# 30830  Williamstown North        6 Edina St      3    h     SP           Greg
#
#              Date  Distance  Postcode  Bedroom  ...  Landsize  BuildingArea  \
# 0        3/9/2016       2.5    3067.0      2.0  ...     126.0           inf
# 3        3/9/2016       3.3    3206.0      2.0  ...     159.0           inf
# 6        3/9/2016       6.4    3078.0      3.0  ...     208.0           inf
# 11       3/9/2016      11.1    3025.0      NaN  ...       NaN       missing
# 12       3/9/2016       6.3    3143.0      2.0  ...     305.0       missing
# ...           ...       ...       ...      ...  ...       ...           ...
# 30551  27/05/2017      31.7    3337.0      3.0  ...     600.0        122.86
# 30606  27/05/2017      22.7    3174.0      3.0  ...     587.0         114.2
# 30767  27/05/2017      10.2    3127.0      5.0  ...     739.0        266.53
# 30829  27/05/2017       6.8    3016.0      2.0  ...     169.0         78.54
# 30830  27/05/2017       6.8    3016.0      3.0  ...     353.0         85.35
#
#        YearBuilt                     CouncilArea  Latitude Longtitude  \
# 0            NaN              Yarra City Council -37.80140  144.99580
# 3            NaN       Port Phillip City Council -37.84500  144.95380
# 6         2013.0            Darebin City Council -37.78540  145.03250
# 11           NaN        Hobsons Bay City Council       NaN        NaN
# 12           NaN        Stonnington City Council -37.85730  145.02260
# ...          ...                             ...       ...        ...
# 30551     1975.0             Melton City Council -37.68734  144.58001
# 30606     1960.0  Greater Dandenong City Council -37.96968  145.16832
# 30767     1927.0         Boroondara City Council -37.81708  145.09566
# 30829     2000.0        Hobsons Bay City Council -37.86682  144.90003
# 30830     1940.0        Hobsons Bay City Council -37.85432  144.88214
#
#                        Regionname  Propertycount      ParkingArea      Price
# 0           Northern Metropolitan         4019.0          Carport        NaN
# 3           Southern Metropolitan         3280.0           Indoor  1455000.0
# 6           Northern Metropolitan         2211.0    Outdoor Stall  1110000.0
# 11           Western Metropolitan         5132.0           Indoor   857500.0
# 12          Southern Metropolitan         4836.0          Parkade        NaN
# ...                           ...            ...              ...        ...
# 30551            Western Victoria         3600.0      Parking Pad   295000.0
# 30606  South-Eastern Metropolitan        11806.0          Parkade   676000.0
# 30767       Southern Metropolitan         5457.0          Carport  2505000.0
# 30829        Western Metropolitan         6380.0  Detached Garage   880000.0
# 30830        Western Metropolitan          802.0  Attached Garage   862000.0
#
# [180 rows x 22 columns]

# %%
Data['BuildingArea'].dtype
# Out:
# dtype('O')

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0e92ea">1.5a  Checking the dataset missing values

# %%
Data['BuildingArea'] = Data['BuildingArea'].astype(str)
Data['BuildingArea'] = Data['BuildingArea'].replace(['inf', 'missing'], np.nan)
Data['BuildingArea'] = pd.to_numeric(Data['BuildingArea'],errors='coerce')

# %%
def missing_check(df):
    total = df.isnull().sum().sort_values(ascending=False)   # total number of null values
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)  # percentage of values that are null
    Datatype = df.dtypes
    missing_data = pd.concat([total, percent, Datatype], axis=1, keys=['Total', 'Percent','Datatype'])  # putting the above two together
    return missing_data # return the dataframe
missing_check(Data)
# Out:
#                Total   Percent Datatype
# BuildingArea   21115  0.605761  float64
# YearBuilt      19306  0.553863  float64
# Landsize       11810  0.338813  float64
# Car             8728  0.250394  float64
# Bathroom        8226  0.235993  float64
# Bedroom         8217  0.235735  float64
# Longtitude      7976  0.228821  float64
# Latitude        7976  0.228821  float64
# Price           7610  0.218321  float64
# CouncilArea        3  0.000086   object
# Propertycount      3  0.000086  float64
# Postcode           1  0.000029  float64
# Distance           1  0.000029  float64
# Address            0  0.000000   object
# Date               0  0.000000   object
# SellerG            0  0.000000   object
# Method             0  0.000000   object
# Type               0  0.000000   object
# Rooms              0  0.000000    int64
# Regionname         0  0.000000   object
# ParkingArea        0  0.000000   object
# Suburb             0  0.000000   object

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0e92ea">1.5b Replace NaN with Median for All Non-Object Columns

# %%
for col in Data.columns:
    if Data[col].dtype != 'object':   # numeric column
        Data[col] = Data[col].fillna(Data[col].mean())

# %%
missing_check(Data)
# Out:
#                Total   Percent Datatype
# CouncilArea        3  0.000086   object
# Suburb             0  0.000000   object
# Address            0  0.000000   object
# ParkingArea        0  0.000000   object
# Propertycount      0  0.000000  float64
# Regionname         0  0.000000   object
# Longtitude         0  0.000000  float64
# Latitude           0  0.000000  float64
# YearBuilt          0  0.000000  float64
# BuildingArea       0  0.000000  float64
# Landsize           0  0.000000  float64
# Car                0  0.000000  float64
# Bathroom           0  0.000000  float64
# Bedroom            0  0.000000  float64
# Postcode           0  0.000000  float64
# Distance           0  0.000000  float64
# Date               0  0.000000   object
# SellerG            0  0.000000   object
# Method             0  0.000000   object
# Type               0  0.000000   object
# Rooms              0  0.000000    int64
# Price              0  0.000000  float64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.7em;color:#00b3e5;">EDA Descriptive Statistics

# %% [markdown]
# ### Mean

# %%
print(Data.mean(numeric_only=True))  # print the mean of each attribute. Ignore "Serial No. as it is not a continuous variable"
# Out:
# Rooms            3.031012e+00
# Distance         1.118493e+01
# Postcode         3.116063e+03
# Bedroom          3.084647e+00
# Bathroom         1.624798e+00
# Car              1.728845e+00
# Landsize         5.935990e+02
# BuildingArea     1.602564e+02
# YearBuilt        1.965290e+03
# Latitude        -3.781063e+01
# Longtitude       1.450019e+02
# Propertycount    7.572888e+03
# Price            1.050173e+06
# dtype: float64

# %% [markdown]
# ### Mode

# %%
print(Data['Price'].mode())  # print the mode of each attribute. Ignore "Serial No. as it is not a continuous variable"
# Out:
# 0    1.050173e+06
# Name: Price, dtype: float64

# %% [markdown]
# ### Median

# %%
print(Data.median(numeric_only=True))  # print the median of each attribute. Ignore "Serial No. as it is not a continuous variable"
# Out:
# Rooms            3.000000e+00
# Distance         1.030000e+01
# Postcode         3.103000e+03
# Bedroom          3.000000e+00
# Bathroom         1.624798e+00
# Car              1.728845e+00
# Landsize         5.935990e+02
# BuildingArea     1.602564e+02
# YearBuilt        1.965290e+03
# Latitude        -3.781063e+01
# Longtitude       1.450019e+02
# Propertycount    6.763000e+03
# Price            1.050173e+06
# dtype: float64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">Univariate Analsyis

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.5a) Plotting the summary mean,mode,median using histogram for GRE and TOEFL scores

# %%
mean=Data['Price'].mean()
median=Data['Price'].median()
mode=Data['Price'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(Data['Price'],bins=50,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     # Draw lines on the plot for mean median and the two modes we have in GRE Score
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode1')

plt.xlabel('Housing Price')   # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  1050173.344955408
# Median:  1050173.344955408
# Mode:  1050173.344955408

# %%
sns.displot(Data['Price'],kind='hist');

# %%
sns.distplot(Data['Price'], hist_kws=dict(cumulative=True), kde_kws=dict(cumulative=True));

# %% [markdown]
#  <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.6 Check the Measures of Dispersion:

# %%
Data['Price'].quantile(0.75) - Data['Price'].quantile(0.25)
# Out:
# 455000.0

# %% [markdown]
# ### Range

# %%
print(Data['Price'].max() - Data['Price'].min())
# Out:
# 11115000.0

# %% [markdown]
# ### Variance

# %%
print(Data.var(numeric_only=True))
# Out:
# Rooms            9.407699e-01
# Distance         4.608774e+01
# Postcode         1.188587e+04
# Bedroom          7.350276e-01
# Bathroom         4.007053e-01
# Car              7.658328e-01
# Landsize         7.638005e+06
# BuildingArea     6.347575e+04
# YearBuilt        6.216221e+02
# Latitude         6.285275e-03
# Longtitude       1.113615e-02
# Propertycount    1.960630e+07
# Price            3.216429e+11
# dtype: float64

# %% [markdown]
# ### Standard Deviation

# %%
print(Data.std(numeric_only=True))
# Out:
# Rooms                 0.969933
# Distance              6.788795
# Postcode            109.022339
# Bedroom               0.857337
# Bathroom              0.633013
# Car                   0.875119
# Landsize           2763.694121
# BuildingArea        251.943934
# YearBuilt            24.932350
# Latitude              0.079280
# Longtitude            0.105528
# Propertycount      4427.899750
# Price            567135.731186
# dtype: float64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.7 Check Covariance and Correlation

# %% [markdown]
# ### Covariance

# %%
Data.cov(numeric_only=True)# Prints the covariance of each attribute against every other attribute
# Out:
#                        Rooms       Distance      Postcode        Bedroom  \
# Rooms               0.940770       1.787812  9.082369e+00       0.681130
# Distance            1.787812      46.087739  3.564218e+02       1.391577
# Postcode            9.082369     356.421767  1.188587e+04       7.514685
# Bedroom             0.681130       1.391577  7.514685e+00       0.735028
# Bathroom            0.324913       0.481046  7.460955e+00       0.333621
# Car                 0.286710       1.258112  5.795578e+00       0.289199
# Landsize           80.783513     914.036668  9.777941e+03      81.930236
# BuildingArea       24.062433      85.708338  8.034878e+02      23.779353
# YearBuilt          -0.209426      37.365472  1.723933e+02      -0.033968
# Latitude            0.000327      -0.048174 -1.802483e+00       0.000233
# Longtitude          0.009226       0.128318  3.768725e+00       0.009561
# Propertycount    -307.827376    -545.291207  8.258666e+03    -173.810466
# Price          222733.419768 -719395.884833  2.504842e+06  159232.078794
#
#                     Bathroom           Car      Landsize  BuildingArea  \
# Rooms               0.324913      0.286710  8.078351e+01  2.406243e+01
# Distance            0.481046      1.258112  9.140367e+02  8.570834e+01
# Postcode            7.460955      5.795578  9.777941e+03  8.034878e+02
# Bedroom             0.333621      0.289199  8.193024e+01  2.377935e+01
# Bathroom            0.400705      0.169252  5.949339e+01  1.722283e+01
# Car                 0.169252      0.765833  8.427786e+01  1.649428e+01
# Landsize           59.493393     84.277856  7.638005e+06  5.962775e+04
# BuildingArea       17.222826     16.494278  5.962775e+04  6.347575e+04
# YearBuilt           2.055583      2.077384  7.255526e+02  8.740334e+01
# Latitude           -0.002956     -0.000620  4.981128e+00  2.501998e-01
# Longtitude          0.007085      0.004305 -6.776348e-01 -4.154216e-02
# Propertycount     -78.951276    -31.662327 -1.768701e+05 -1.673701e+04
# Price          116543.820473  76702.370430  4.147380e+07  9.330570e+06
#
#                   YearBuilt     Latitude   Longtitude  Propertycount  \
# Rooms         -2.094258e-01     0.000327     0.009226  -3.078274e+02
# Distance       3.736547e+01    -0.048174     0.128318  -5.452912e+02
# Postcode       1.723933e+02    -1.802483     3.768725   8.258666e+03
# Bedroom       -3.396828e-02     0.000233     0.009561  -1.738105e+02
# Bathroom       2.055583e+00    -0.002956     0.007085  -7.895128e+01
# Car            2.077384e+00    -0.000620     0.004305  -3.166233e+01
# Landsize       7.255526e+02     4.981128    -0.677635  -1.768701e+05
# BuildingArea   8.740334e+01     0.250200    -0.041542  -1.673701e+04
# YearBuilt      6.216221e+02     0.137437    -0.044190   1.606269e+03
# Latitude       1.374373e-01     0.006285    -0.002891   3.360970e+00
# Longtitude    -4.419033e-02    -0.002891     0.011136   6.572876e+00
# Propertycount  1.606269e+03     3.360970     6.572876   1.960630e+07
# Price         -2.839168e+06 -7681.390765  9268.942130  -1.329294e+08
#
#                       Price
# Rooms          2.227334e+05
# Distance      -7.193959e+05
# Postcode       2.504842e+06
# Bedroom        1.592321e+05
# Bathroom       1.165438e+05
# Car            7.670237e+04
# Landsize       4.147380e+07
# BuildingArea   9.330570e+06
# YearBuilt     -2.839168e+06
# Latitude      -7.681391e+03
# Longtitude     9.268942e+03
# Propertycount -1.329294e+08
# Price          3.216429e+11

# %% [markdown]
# ### Correlation

# %%
Data.corr(numeric_only=True)
# Out:
#                   Rooms  Distance  Postcode   Bedroom  Bathroom       Car  \
# Rooms          1.000000  0.271511  0.085890  0.819099  0.529191  0.337780
# Distance       0.271511  1.000000  0.481566  0.239091  0.111939  0.211768
# Postcode       0.085890  0.481566  1.000000  0.080398  0.108110  0.060746
# Bedroom        0.819099  0.239091  0.080398  1.000000  0.614737  0.385459
# Bathroom       0.529191  0.111939  0.108110  0.614737  1.000000  0.305530
# Car            0.337780  0.211768  0.060746  0.385459  0.305530  1.000000
# Landsize       0.030136  0.048717  0.032452  0.034578  0.034007  0.034846
# BuildingArea   0.098468  0.050110  0.029252  0.110089  0.107991  0.074810
# YearBuilt     -0.008660  0.220757  0.063422 -0.001589  0.130244  0.095211
# Latitude       0.004254 -0.089506 -0.208542  0.003431 -0.058905 -0.008943
# Longtitude     0.090140  0.179113  0.327576  0.105682  0.106059  0.046613
# Propertycount -0.071675 -0.018140  0.017108 -0.045785 -0.028168 -0.008171
# Price          0.404908 -0.186848  0.040511  0.327485  0.324631  0.154545
#
#                Landsize  BuildingArea  YearBuilt  Latitude  Longtitude  \
# Rooms          0.030136      0.098468  -0.008660  0.004254    0.090140
# Distance       0.048717      0.050110   0.220757 -0.089506    0.179113
# Postcode       0.032452      0.029252   0.063422 -0.208542    0.327576
# Bedroom        0.034578      0.110089  -0.001589  0.003431    0.105682
# Bathroom       0.034007      0.107991   0.130244 -0.058905    0.106059
# Car            0.034846      0.074810   0.095211 -0.008943    0.046613
# Landsize       1.000000      0.085636   0.010530  0.022734   -0.002323
# BuildingArea   0.085636      1.000000   0.013914  0.012526   -0.001562
# YearBuilt      0.010530      0.013914   1.000000  0.069531   -0.016796
# Latitude       0.022734      0.012526   0.069531  1.000000   -0.345589
# Longtitude    -0.002323     -0.001562  -0.016796 -0.345589    1.000000
# Propertycount -0.014453     -0.015003   0.014550  0.009574    0.014067
# Price          0.026460      0.065301  -0.200789 -0.170840    0.154873
#
#                Propertycount     Price
# Rooms              -0.071675  0.404908
# Distance           -0.018140 -0.186848
# Postcode            0.017108  0.040511
# Bedroom            -0.045785  0.327485
# Bathroom           -0.028168  0.324631
# Car                -0.008171  0.154545
# Landsize           -0.014453  0.026460
# BuildingArea       -0.015003  0.065301
# YearBuilt           0.014550 -0.200789
# Latitude            0.009574 -0.170840
# Longtitude          0.014067  0.154873
# Propertycount       1.000000 -0.052934
# Price              -0.052934  1.000000

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> 1.8a. Pairplot for checking the correlation

# %%
# sns.pairplot(Data, kind="reg")  # plots scatter plots for every pair of attributes and histograms along the diagonal
# plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> 1.8b. Heatmap for checking the correlation

# %%
fig,ax = plt.subplots(figsize=(10, 10))   
sns.heatmap(Data.corr(numeric_only=True), ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma") # the color intensity is based on 
plt.show()

# %%
Data.skew(numeric_only=True)   # to measure the skeweness of every attribute
# Out:
# Rooms              0.499097
# Distance           1.503607
# Postcode           4.018843
# Bedroom            1.608683
# Bathroom           1.551669
# Car                2.419903
# Landsize         118.086535
# BuildingArea     157.872948
# YearBuilt         -1.618205
# Latitude          -0.293404
# Longtitude        -0.449658
# Propertycount      0.992143
# Price              2.928245
# dtype: float64

# %%
sns.scatterplot(data= Data, y='Price',x='Rooms',hue='Bathroom')
# Out:
# <Axes: xlabel='Rooms', ylabel='Price'>

# %% [markdown]
# # <span style="font-family: Arial; font-weight:bold;font-size:1.6em;color:#0e92ea"> Handling non-numeric(Categorical) data

# %%
# Make list of all columns with Object datatype

Obj_dtype = [ col for col in Data.columns if Data[col].dtype == 'object' ]
Obj_dtype
# Out:
# ['Suburb',
#  'Address',
#  'Type',
#  'Method',
#  'SellerG',
#  'Date',
#  'CouncilArea',
#  'Regionname',
#  'ParkingArea']

# %%
for col in Obj_dtype:
    print(Data[col].value_counts())
    print()
# Out:
# Suburb
# Reservoir         844
# Bentleigh East    583
# Richmond          552
# Glen Iris         491
# Preston           485
#                  ...
# Avonsleigh          1
# Wandin North        1
# Ferny Creek         1
# Guys Hill           1
# viewbank            1
# Name: count, Length: 351, dtype: int64
#
# Address
# 5 Charles St         6
# 25 William St        4
# 33 McCracken St      3
# 14 Northcote St      3
# 1 Bruce St           3
#                     ..
# 158 Eglinton St      1
# 220 Cotham Rd        1
# 302/108 Altona St    1
# 13 Albermarle St     1
# 42 Pascoe St         1
# Name: count, Length: 34009, dtype: int64
#
# Type
# h    23980
# u     7297
# t     3580
# Name: count, dtype: int64
#
# Method
# S     19744
# SP     5095
# PI     4850
# VB     3108
# SN     1317
# PN      308
# SA      226
# W       173
# SS       36
# Name: count, dtype: int64
#
# SellerG
# Jellis           3359
# Nelson           3236
# Barry            3235
# hockingstuart    2623
# Marshall         2027
#                  ...
# Knight              1
# Allan               1
# Black               1
# Batty               1
# Icon                1
# Name: count, Length: 388, dtype: int64
#
# Date
# 28/10/2017    1119
# 17/03/2018     970
# 24/02/2018     941
# 9/12/2017      927
# 25/11/2017     902
#               ...
# 4/2/2016        44
# 30/09/2017      22
# 20/01/2018      19
# 27/01/2018      12
# 28/01/2016       3
# Name: count, Length: 78, dtype: int64
#
# CouncilArea
# Boroondara City Council           3675
# Darebin City Council              2851
# Moreland City Council             2122
# Glen Eira City Council            2006
# Melbourne City Council            1952
# Banyule City Council              1861
# Moonee Valley City Council        1791
# Bayside City Council              1764
# Brimbank City Council             1593
# Monash City Council               1466
# Stonnington City Council          1460
# Maribyrnong City Council          1451
# Port Phillip City Council         1280
# Hume City Council                 1214
# Yarra City Council                1186
# Manningham City Council           1046
# Hobsons Bay City Council           942
# Kingston City Council              871
# Whittlesea City Council            828
# Wyndham City Council               624
# Whitehorse City Council            618
# Maroondah City Council             506
# Knox City Council                  371
# Greater Dandenong City Council     314
# Melton City Council                292
# Frankston City Council             290
# Casey City Council                 176
# Yarra Ranges Shire Council         102
# Nillumbik Shire Council             88
# Macedon Ranges Shire Council        46
# Cardinia Shire Council              41
# Mitchell Shire Council              20
# Moorabool Shire Council              7
# Name: count, dtype: int64
#
# Regionname
# Southern Metropolitan         11836
# Northern Metropolitan          9560
# Western Metropolitan           6799
# Eastern Metropolitan           4377
# South-Eastern Metropolitan     1739
# Eastern Victoria                228
# Northern Victoria               203
# Western Victoria                115
# Name: count, dtype: int64
#
# ParkingArea
# Carport            6243
# Detached Garage    6243
# Attached Garage    6243
# Indoor             5722
# Parkade            4682
# Underground        2602
# Outdoor Stall      2081
# Parking Pad        1041
# Name: count, dtype: int64

# %%
# Type, Method, regionname and ParkingArea can be label encoded

# %%
df_dummies = Data.copy()

# %%
df_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Method         34857 non-null  object
#  5   SellerG        34857 non-null  object
#  6   Date           34857 non-null  object
#  7   Distance       34857 non-null  float64
#  8   Postcode       34857 non-null  float64
#  9   Bedroom        34857 non-null  float64
#  10  Bathroom       34857 non-null  float64
#  11  Car            34857 non-null  float64
#  12  Landsize       34857 non-null  float64
#  13  BuildingArea   34857 non-null  float64
#  14  YearBuilt      34857 non-null  float64
#  15  CouncilArea    34854 non-null  object
#  16  Latitude       34857 non-null  float64
#  17  Longtitude     34857 non-null  float64
#  18  Regionname     34857 non-null  object
#  19  Propertycount  34857 non-null  float64
#  20  ParkingArea    34857 non-null  object
#  21  Price          34857 non-null  float64
# dtypes: float64(12), int64(1), object(9)
# memory usage: 5.9+ MB

# %%
## Label Encoding

from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df_dummies['RegionID'] = labelencoder.fit_transform(df_dummies.Regionname)
df_dummies['Type'] = labelencoder.fit_transform(df_dummies.Type)
df_dummies['Method'] = labelencoder.fit_transform(df_dummies.Method)
df_dummies['ParkingArea'] = labelencoder.fit_transform(df_dummies.ParkingArea)

# %%
df_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  int64
#  4   Method         34857 non-null  int64
#  5   SellerG        34857 non-null  object
#  6   Date           34857 non-null  object
#  7   Distance       34857 non-null  float64
#  8   Postcode       34857 non-null  float64
#  9   Bedroom        34857 non-null  float64
#  10  Bathroom       34857 non-null  float64
#  11  Car            34857 non-null  float64
#  12  Landsize       34857 non-null  float64
#  13  BuildingArea   34857 non-null  float64
#  14  YearBuilt      34857 non-null  float64
#  15  CouncilArea    34854 non-null  object
#  16  Latitude       34857 non-null  float64
#  17  Longtitude     34857 non-null  float64
#  18  Regionname     34857 non-null  object
#  19  Propertycount  34857 non-null  float64
#  20  ParkingArea    34857 non-null  int64
#  21  Price          34857 non-null  float64
#  22  RegionID       34857 non-null  int64
# dtypes: float64(12), int64(5), object(6)
# memory usage: 6.1+ MB

# %%
df_dummies
# Out:
#                  Suburb           Address  Rooms  Type  Method        SellerG  \
# 0            Abbotsford     68 Studley St      2     0       6         Jellis
# 1          Airport West     154 Halsey Rd      3     1       0         Nelson
# 2           Albert Park    105 Kerferd Rd      2     0       2  hockingstuart
# 3           Albert Park  85 Richardson St      2     0       2        Thomson
# 4            Alphington      30 Austin St      3     0       4        McGrath
# ...                 ...               ...    ...   ...     ...            ...
# 34852         Reservoir      18 Elinda Pl      3     2       5             RW
# 34853     Roxburgh Park    14 Stainsby Cr      4     0       2          Raine
# 34854  Springvale South     8 Bellbird Ct      4     0       0          Barry
# 34855  Springvale South  30 Waddington Cr      3     0       2      Harcourts
# 34856       Westmeadows      42 Pascoe St      4     0       2          Barry
#
#              Date  Distance  Postcode  Bedroom  ...  BuildingArea  \
# 0        3/9/2016       2.5    3067.0      2.0  ...      160.2564
# 1        3/9/2016      13.5    3042.0      3.0  ...      225.0000
# 2        3/9/2016       3.3    3206.0      2.0  ...       82.0000
# 3        3/9/2016       3.3    3206.0      2.0  ...      160.2564
# 4        3/9/2016       6.4    3078.0      3.0  ...      122.0000
# ...           ...       ...       ...      ...  ...           ...
# 34852  30/09/2017      12.0    3073.0      3.0  ...      105.0000
# 34853  30/09/2017      20.6    3064.0      4.0  ...      225.0000
# 34854  30/09/2017      22.2    3172.0      4.0  ...      152.0000
# 34855  30/09/2017      22.2    3172.0      3.0  ...      160.2564
# 34856  30/09/2017      16.5    3049.0      4.0  ...      140.0000
#
#          YearBuilt                     CouncilArea  Latitude  Longtitude  \
# 0      1965.289885              Yarra City Council -37.80140   144.99580
# 1      2016.000000      Moonee Valley City Council -37.71800   144.87800
# 2      1900.000000       Port Phillip City Council -37.84590   144.95550
# 3      1965.289885       Port Phillip City Council -37.84500   144.95380
# 4      2003.000000            Darebin City Council -37.78180   145.01980
# ...            ...                             ...       ...         ...
# 34852  1990.000000            Darebin City Council -37.69769   145.02332
# 34853  1995.000000               Hume City Council -37.63665   144.92976
# 34854  1970.000000  Greater Dandenong City Council -37.97037   145.15449
# 34855  1965.289885  Greater Dandenong City Council -37.97751   145.14813
# 34856  1960.000000               Hume City Council -37.67631   144.89409
#
#                        Regionname  Propertycount  ParkingArea         Price  \
# 0           Northern Metropolitan         4019.0            1  1.050173e+06
# 1            Western Metropolitan         3464.0            2  8.400000e+05
# 2           Southern Metropolitan         3280.0            0  1.275000e+06
# 3           Southern Metropolitan         3280.0            3  1.455000e+06
# 4           Northern Metropolitan         2211.0            5  1.050173e+06
# ...                           ...            ...          ...           ...
# 34852       Northern Metropolitan        21650.0            5  4.750000e+05
# 34853       Northern Metropolitan         5833.0            7  5.910000e+05
# 34854  South-Eastern Metropolitan         4054.0            1  1.050173e+06
# 34855  South-Eastern Metropolitan         4054.0            2  7.805000e+05
# 34856       Northern Metropolitan         2474.0            0  7.910000e+05
#
#        RegionID
# 0             2
# 1             6
# 2             5
# 3             5
# 4             2
# ...         ...
# 34852         2
# 34853         2
# 34854         4
# 34855         4
# 34856         2
#
# [34857 rows x 23 columns]
